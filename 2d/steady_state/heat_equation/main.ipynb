# %%
from generate_mesh import create_msh, convert_mesh_to_xdmf
# from solver import solve_thermal_problem
# from dolfin import plot

_num_segments = 6

create_msh(length=1.0,
           num_segments=_num_segments,
           mesh_size=0.1,
           mesh_file="mesh/square_mesh.msh")
convert_mesh_to_xdmf("mesh/square_mesh.msh","mesh/mesh.xdmf", "mesh/line.xdmf")
#u_sol = solve_thermal_problem("mesh/mesh.xdmf", "mesh/line.xdmf", "output/thermal.xdmf", top_temp=100.0, left_temp=50.0, bottom_temp=25.0,num_segments = _num_segments)
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 20%] Meshing curve 2 (Line)
# Info    : [ 30%] Meshing curve 3 (Line)
# Info    : [ 40%] Meshing curve 4 (Line)
# Info    : [ 50%] Meshing curve 5 (Line)
# Info    : [ 60%] Meshing curve 6 (Line)
# Info    : [ 70%] Meshing curve 7 (Line)
# Info    : [ 80%] Meshing curve 8 (Line)
# Info    : [ 90%] Meshing curve 9 (Line)
# Info    : Done meshing 1D (Wall 0.000816837s, CPU 0.001774s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00375892s, CPU 0.009567s)
# Info    : 156 nodes 319 elements
# Info    : Writing 'mesh/square_mesh.msh'...
# Info    : Done writing 'mesh/square_mesh.msh'

# %%
plot(u_sol)
